# %% [markdown]
# # Ontology approach using Flavor wheel from the Scotch Whiskey Research Institute

# %%
import pandas as pd
import csv
from fuzzywuzzy import process
from fuzzywuzzy import fuzz
import numpy as np
from scipy import stats
# Out:
# c:\Users\Franz\AppData\Local\Programs\Python\Python39\lib\site-packages\fuzzywuzzy\fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %% [markdown]
# *Flavornet data*

# %%
# only using flavornet data
mol_to_OD = {}
CAS_OD = {}
molecules = []
descriptors = []
with open('./data/CAS_mol_OD.csv', 'r',encoding='utf-8') as tabfile:
    reader = csv.reader(tabfile, delimiter=',')
    for row in reader: 
        molecule = row[0]
        CAS = row[1]
        OD = row[3]
        molecules.append(molecule)
        descriptors.append(OD)
        if CAS in mol_to_OD:
            mol_to_OD[CAS].add(OD)
        else:
            mol_to_OD[CAS]  = set([OD])

molecules = list(set(molecules))
descriptors = list(set(descriptors))

# %%
# key = CAS (727), value = odorant (197)
# 727 cas numbers
mol_to_OD
# Out:
# {'6485-40-1': {'mint'},
#  '3033-23-6': {'rose', 'sweet'},
#  '21284-22-0': {'green tea', 'herb', 'spice'},
#  '38427-78-0': {'terpentine'},
#  '495-61-4': {'balsamic'},
#  '29873-99-2': {'green', 'oil', 'wood'},
#  '6909-30-4': {'green'},
#  '99-49-0': {'basil', 'caraway', 'fennel', 'mint'},
#  '2244-16-8': {'caraway'},
#  '876-17-5': {'flower', 'green'},
#  '5989-27-5': {'citrus', 'mint'},
#  '4674-50-4': {'grapefruit'},
#  '2243-33-6': {'dill'},
#  '10307-61-6': {'apple'},
#  '69064-37-5': {'oil'},
#  '85761-70-2': {'green', 'leaf'},
#  '6728-26-3': {'apple', 'fat', 'green', 'leaf', 'rancid'},
#  '13419-69-7': {'fat', 'must'},
#  '928-95-0': {'green', 'leaf', 'walnut'},
#  '18829-56-6': {'cucumber', 'fat', 'green'},
#  '1576-96-1': {'mushroom'},
#  '53448-07-0': {'fat', 'green', 'soap'},
#  '928-97-2': {'fresh', 'moss'},
#  '1197-07-5': {'caraway', 'solvent'},
#  '14371-10-9': {'cinnamon', 'paint'},
#  '09.04.5948': {'herb', 'warm'},
#  '106-28-5': {'muguet'},
#  '5273-85-8': {'flower', 'spice'},
#  '5932-68-3': {'flower'},
#  '4959-35-7': {'citrus', 'fresh'},
#  '34995-77-2': {'flower'},
#  '39638-67-0': {'coconut', 'flower'},
#  '7212-40-0': {'fresh', 'mint'},
#  '07.11.5258': {'flower'},
#  '80041-01-6': {'flower', 'lactone'},
#  '13474-59-4': {'tea', 'warm', 'wood'},
#  '23726-91-2': {'apple'},
#  '3779-61-1': {'herb', 'sweet'},
#  '4128-17-0': {'oil', 'wax'},
#  '1117-52-8': {'ether', 'flower'},
#  '21661-99-4': {'geranium', 'pungent'},
#  '56805-23-3': {'fish'},
#  '92356-06-4': {'citrus', 'earth', 'green'},
#  '15186-51-3': {'mint'},
#  '125811-37-2': {'mint'},
#  '1576-95-0': {'green', 'plastic', 'rubber'},
#  '928-96-1': {'grass'},
#  '53398-85-9': {'herb', 'sweet'},
#  '16491-36-4': {'green', 'wine'},
#  '31501-11-8': {'fruit', 'prune'},
#  '21662-09-9': {'green', 'must'},
#  '15456-69-6': {'soap'},
#  '18679-18-0': {'peach', 'sweet'},
#  '1197-06-4': {'caraway'},
#  '3792-53-8': {'herb', 'warm'},
#  '13837-75-7': {'citrus', 'fresh'},
#  '5989-33-3': {'flower'},
#  '3790-78-1': {'wax'},
#  '55013-32-6': {'spice'},
#  '3338-55-4': {'citrus', 'flower', 'herb'},
#  '491-04-3': {'herb'},
#  '80041-00-5': {'coconut'},
#  '28973-97-9': {'citrus', 'green'},
#  '31331-53-0': {'thiamin'},
#  '930-68-7': {'pesticide'},
#  '4798-44-1': {'green'},
#  '562-74-3': {'must', 'nutmeg', 'turpentine'},
#  '1197-15-5': {'fat', 'spice'},
#  '470-67-7': {'spice'},
#  '83861-74-9': {'earth', 'herb'},
#  '359794-78-8': {'earth', 'must'},
#  '470-82-6': {'mint', 'sweet'},
#  '15051-81-7': {'flower', 'sweet', 'wood'},
#  '75853-49-5': {'cooked meat', 'fat', 'meat broth', 'sweat', 'tallow'},
#  '25343-57-1': {'caramel'},
#  '27300-27-2': {'caramel'},
#  '1072-83-9': {'bread', 'nut', 'walnut'},
#  '2497-25-8': {'orange', 'tallow'},
#  '3913-71-1': {'orange', 'tallow'},
#  '3913-81-3': {'orange', 'tallow'},
#  '20407-84-5': {'fat', 'green', 'sweet'},
#  '104-76-7': {'green', 'rose'},
#  '100-71-0': {'grass'},
#  '98-03-3': {'sulfur'},
#  '2463-63-0': {'green'},
#  '505-57-7': {'apple', 'fat', 'green', 'rancid'},
#  '928-94-9': {'fruit', 'green', 'leaf', 'wine'},
#  '19846-22-1': {'earth'},
#  '137-32-6': {'malt', 'onion', 'wine'},
#  '67952-60-7': {'fat', 'smoke'},
#  '578-58-5': {'flower', 'walnut', 'warm'},
#  '624-41-9': {'fruit'},
#  '628-99-9': {'cucumber'},
#  '2463-53-8': {'cucumber', 'fat', 'orris', 'paper'},
#  '60784-31-8': {'cucumber', 'fat', 'orris', 'paper'},
#  '123-96-6': {'fat', 'mushroom'},
#  '20664-46-4': {'fat', 'green', 'green leaf', 'nut', 'walnut'},
#  '2548-87-0': {'fat', 'green', 'green leaf', 'nut', 'walnut'},
#  '2363-89-5': {'fat', 'green', 'green leaf', 'nut', 'walnut'},
#  '6032-29-7': {'green'},
#  '4861-58-9': {'fruit', 'sweet'},
#  '60-12-8': {'honey', 'lilac', 'rose', 'spice'},
#  '2463-77-6': {'sweet'},
#  '92760-25-3': {'lemon', 'mint'},
#  '600-14-6': {'butter', 'cream'},
#  '931-57-7': {'herb', 'spice'},
#  '65909-91-3': {'seaweed'},
#  '04.02.4313': {'fat', 'fried', 'nut'},
#  '05.03.4313': {'fat', 'fried', 'nut'},
#  '80466-34-8': {'green'},
#  '04.03.6750': {'fat', 'green', 'watermelon', 'wax'},
#  '5910-87-2': {'fat', 'green', 'watermelon', 'wax'},
#  '30361-28-5': {'cucumber', 'green', 'seaweed'},
#  '13360-65-1': {'potato', 'roast'},
#  '581-42-0': {'grass'},
#  '557-48-2': {'cucumber', 'green', 'wax'},
#  '7786-44-9': {'cucumber'},
#  '55764-25-5': {'roasted meat'},
#  '6789-80-6': {'green', 'leaf'},
#  '51755-83-0': {'sulfur'},
#  '136954-20-6': {'box tree'},
#  '7774-73-4': {'cooked meat'},
#  '123-51-3': {'burnt', 'malt', 'whiskey'},
#  '109351-28-2': {'cucumber', 'fat'},
#  '31823-43-5': {'cucumber', 'fat'},
#  '1669-44-9': {'crushed bug', 'nut'},
#  '51193-77-2': {'nut'},
#  '34318-21-3': {'spice'},
#  '586-82-3': {'must'},
#  '38284-27-4': {'fat', 'fruit', 'mushroom'},
#  '21944-83-2': {'fat', 'soap'},
#  '122-00-9': {'bitter almond'},
#  '1126-51-8': {'roast', 'smoke'},
#  '131671-56-2': {'fish'},
#  '2785-89-9': {'clove', 'spice'},
#  '6728-31-0': {'biscuit', 'cream'},
#  '695-06-7': {'coumarin', 'sweet'},
#  '31539-84-1': {'flower', 'lemon'},
#  '19872-52-7': {'box tree'},
#  '141-79-7': {'chemical', 'sweet'},
#  '818-49-5': {'sweat'},
#  '693-95-8': {'roasted meat'},
#  '34047-39-7': {'fruit'},
#  '18060-79-2': {'horseradish', 'mustard'},
#  '2785-87-7': {'phenol'},
#  '2628-17-3': {'almond shell'},
#  '59121-25-4': {'broccoli', 'cabbage'},
#  '13925-05-8': {'sweat'},
#  '620-02-0': {'almond', 'burnt sugar', 'caramel'},
#  '698-76-0': {'peach'},
#  '67-47-0': {'cardboard'},
#  '105683-99-6': {'cucumber', 'green', 'tallow'},
#  '147159-48-6': {'cucumber', 'green', 'tallow'},
#  '6627-88-9': {'flower', 'sweet'},
#  '18479-58-8': {'citrus', 'cologne', 'tart lime'},
#  '54290-12-9': {'alkane'},
#  '531-59-9': {'balsamic', 'sweet'},
#  '698-10-2': {'spice'},
#  '64-19-7': {'sour'},
#  '513-86-0': {'butter', 'cream'},
#  '98-86-2': {'almond', 'flower', 'must'},
#  '498-02-2': {'vanilla'},
#  '1192-62-7': {'balsamic'},
#  '70286-20-3': {'spice'},
#  '4166-20-5': {'caramel'},
#  '22047-25-2': {'roast'},
#  '1122-62-9': {'popcorn'},
#  '85213-22-5': {'nut', 'roast'},
#  '55041-85-5': {'medicine'},
#  '24295-03-2': {'nut', 'roast', 'sulfur'},
#  '29926-41-8': {'popcorn', 'roast'},
#  '88-15-3': {'sulfur'},
#  '25246-27-9': {'wood'},
#  '1569-50-2': {'green', 'vinyl'},
#  '489-39-4': {'wood'},
#  '29887-38-5': {'herb'},
#  '546-49-6': {'green', 'herb'},
#  '18607-93-7': {'pepper', 'spice'},
#  '110-86-1': {'rancid'},
#  '100-52-7': {'almond', 'burnt sugar'},
#  '65-85-0': {'urine'},
#  '95-16-9': {'gasoline', 'rubber'},
#  '140-11-4': {'boiled vegetable', 'fresh'},
#  '100-51-6': {'flower', 'sweet'},
#  '120-51-4': {'balsamic', 'herb', 'oil'},
#  '103-37-7': {'plum'},
#  '538-86-3': {'metal'},
#  '4430-42-6': {'cabbage'},
#  '24703-35-3': {'green', 'wood'},
#  '28588-75-2': {'roasted meat'},
#  '507-70-0': {'camphor'},
#  '26927-90-2': {'balsamic', 'pine'},
#  '13109-70-1': {'herb', 'wood'},
#  '7492-41-3': {'green'},
#  '76-50-6': {'earth', 'green', 'herb'},
#  '10395-54-7': {'earth', 'must'},
#  '22451-73-6': {'spice'},
#  '123-72-8': {'green', 'pungent'},
#  '513-85-9': {'fruit', 'onion'},
#  '78-92-2': {'fruit', 'medicine', 'wine'},
#  '123-86-4': {'pear'},
#  '136-60-7': {'balsamic'},
#  '30673-36-0': {'whiskey'},
#  '626-82-4': {'fruit'},
#  '592-82-5': {'green', 'pungent', 'sulfur'},
#  '106-18-3': {'oil'},
#  '15706-73-7': {'cocoa', 'fruit'},
#  '589-75-3': {'fruit'},
#  '24168-70-5': {'carrot', 'earth'},
#  '107-92-6': {'cheese', 'rancid', 'sweat'},
#  '114791-16-1': {'spice', 'wood'},
#  '29837-12-5': {'fruit', 'spice'},
#  '483-77-2': {'herb', 'spice'},
#  '79-92-5': {'camphor'},
#  '465-31-6': {'camphor'},
#  '76-22-2': {'camphor'},
#  '142-62-1': {'sweat'},
#  '99-48-9': {'caraway', 'fresh', 'spearmint'},
#  '97-42-7': {'green', 'spearmint'},
#  '56747-96-7': {'earth', 'moss', 'spice'},
#  '1139-30-6': {'herb', 'spice', 'sweet'},
#  '28231-03-0': {'fruit'},
#  '36653-82-4': {'flower', 'wax'},
#  '501-92-8': {'medicine', 'phenol'},
#  '140-10-3': {'honey'},
#  '104-54-1': {'oil'},
#  '72203-97-5': {'green'},
#  '14009-71-3': {'citrus', 'green'},
#  '15537-55-0': {'balsamic'},
#  '5392-40-5': {'lemon'},
#  '106-23-0': {'fat'},
#  '106-22-9': {'rose'},
#  '150-84-5': {'dust', 'rose'},
#  '141-16-2': {'fruit', 'rose', 'sweet'},
#  '97-89-2': {'fruit', 'rose'},
#  '7540-53-6': {'herb', 'honey', 'rose', 'warm'},
#  '91-64-5': {'green', 'sweet'},
#  '122-03-2': {'acid', 'sharp'},
#  '536-60-7': {'herb', 'wood'},
#  '25152-84-5': {'fat', 'fried', 'wax'},
#  '25152-83-4': {'fat', 'fried', 'wax'},
#  '112-31-2': {'orange peel', 'soap', 'tallow'},
#  '124-18-5': {'alkane'},
#  '334-48-5': {'fat', 'rancid'},
#  '112-30-1': {'fat'},
#  '112-17-4': {'oil', 'orange'},
#  '30364-38-6': {'licorice'},
#  '28982-60-7': {'herb', 'oil'},
#  '431-03-8': {'butter'},
#  '69134-53-8': {'cotton candy'},
#  '105-57-7': {'cream', 'fruit'},
#  '03.12.7554': {'brown sugar', 'sweet'},
#  '105-53-3': {'apple'},
#  '123-25-1': {'fruit', 'wine'},
#  '87-91-2': {'earth', 'must'},
#  '18138-04-0': {'meat', 'potato', 'roast'},
#  '18138-05-1': {'baked'},
#  '619-01-2': {'mint', 'spice'},
#  '20777-49-5': {'camphor', 'medicine', 'mint'},
#  '18479-49-7': {'camphor', 'citrus', 'wood'},
#  '23747-48-0': {'nut', 'roast'},
#  '58985-18-5': {'citrus', 'pine'},
#  '484-31-1': {'spice', 'wood'},
#  '74410-10-9': {'dill'},
#  '131092-10-9': {'hummus'},
#  '624-92-0': {'cabbage', 'onion', 'putrid'},
#  '5910-89-4': {'cocoa',
#   'meat',
#   'medicine',
#   'nut',
#   'peanut butter',
#   'roast beef',
#   'roasted nut'},
#  '123-32-0': {'cocoa',
#   'meat',
#   'medicine',
#   'nut',
#   'peanut butter',
#   'roast beef',
#   'roasted nut'},
#  '108-50-9': {'cocoa',
#   'meat',
#   'medicine',
#   'nut',
#   'peanut butter',
#   'roast beef',
#   'roasted nut'},
#  '75-18-3': {'cabbage', 'gasoline', 'sulfur'},
#  '67-71-0': {'burnt', 'sulfur'},
#  '5756-24-1': {'cabbage', 'sulfur'},
#  '3658-80-8': {'cabbage', 'fish', 'sulfur'},
#  '13925-07-0': {'burnt', 'popcorn', 'potato', 'roast'},
#  '55764-23-3': {'meat'},
#  '106-72-9': {'fruit', 'green', 'melon'},
#  '4077-47-8': {'caramel', 'mildew', 'sweet'},
#  '72203-98-6': {'green'},
#  '541-58-2': {'mold', 'roast', 'rubber', 'smoke'},
#  '3581-91-7': {'mold', 'roast', 'rubber', 'smoke'},
#  '629-97-0': {'alkane'},
#  '112-40-3': {'alkane'},
#  '95-93-2': {'rancid', 'sweet'},
#  '112-95-8': {'alkane'},
#  '487-11-6': {'flower', 'spice'},
#  '639-99-6': {'green', 'wood'},
#  '134454-31-2': {'green', 'metal'},
#  '128386-31-2': {'metal'},
#  '134452-45-2': {'metal'},
#  '134346-43-3': {'metal'},
#  '13955-48-1': {'dill', 'mint'},
#  '23267-57-4': {'fruit', 'sweet', 'wood'},
#  '14049-11-7': {'flower'},
#  '4430-36-8': {'cabbage'},
#  '140-67-0': {'anise', 'licorice'},
#  '75-07-0': {'ether', 'pungent'},
#  '64-17-5': {'sweet'},
#  '157615-33-3': {'earth'},
#  '181589-32-2': {'earth'},
#  '111-35-3': {'fruit'},
#  '4192-77-2': {'flower', 'honey'},
#  '3025-30-7': {'pear'},
#  '110516-60-4': {'caramel'},
#  '5405-41-4': {'marshmallow'},
#  '108-64-5': {'apple', 'fruit'},
#  '141-78-6': {'pineapple'},
#  '93-89-0': {'camomile', 'celery', 'flower', 'fruit'},
#  '105-54-4': {'apple'},
#  '103-36-6': {'cinnamon', 'honey'},
#  '3289-28-9': {'fruit'},
#  '110-38-3': {'grape'},
#  '2021-28-5': {'flower'},
#  '109-94-4': {'pungent'},
#  '106-30-9': {'fruit'},
#  '628-97-7': {'wax'},
#  '123-66-0': {'apple peel', 'fruit'},
#  '999-10-0': {'caramel'},
#  '97-62-1': {'rubber', 'sweet'},
#  '25415-67-2': {'fruit'},
#  '97-64-3': {'fruit'},
#  '106-33-2': {'leaf'},
#  '19788-49-9': {'sulfur'},
#  '7452-79-1': {'apple'},
#  '106-32-1': {'fat', 'fruit'},
#  '2351-90-8': {'fruit', 'must', 'oil', 'pungent'},
#  '101-97-3': {'fruit', 'sweet'},
#  '105-37-3': {'fruit'},
#  '13925-00-3': {'peanut butter', 'wood'},
#  '118-61-6': {'mint', 'wintergreen'},
#  '124-06-1': {'ether'},
#  '627-90-7': {'coconut', 'cognac'},
#  '539-82-2': {'fruit', 'yeast'},
#  '617-05-0': {'flower', 'fruit', 'sweet', 'vanilla'},
#  '4748-78-1': {'sweet'},
#  '15707-34-3': {'burnt', 'popcorn', 'potato'},
#  '38205-61-7': {'earth'},
#  '01.01.2313': {'spice'},
#  '2407-43-4': {'spice'},
#  '2305-25-1': {'fresh'},
#  '13360-64-0': {'fruit', 'sweet'},
#  '620-17-7': {'must'},
#  '123123-38-6': {'sweet', 'wood'},
#  '97-53-0': {'clove', 'honey'},
#  '1632-73-1': {'camphor'},
#  '102322-83-8': {'hazelnut', 'nut'},
#  '13679-70-4': {'sulfur'},
#  '33580-05-1': {'green', 'plastic'},
#  '98-02-2': {'coffee', 'roast'},
#  '3658-77-3': {'caramel'},
#  '98-01-1': {'almond', 'bread', 'sweet'},
#  '98-00-0': {'burnt'},
#  '57500-00-2': {'smoke'},
#  '19700-21-1': {'beet', 'earth'},
#  '141-27-5': {'lemon', 'mint'},
#  '106-24-1': {'geranium', 'rose'},
#  '105-87-3': {'rose'},
#  '3796-70-1': {'green', 'magnolia'},
#  '106-29-6': {'apple', 'fruit', 'rose'},
#  '109-20-6': {'apple', 'fruit', 'rose'},
#  '10402-47-8': {'fruit', 'rose'},
#  '15423-57-1': {'earth', 'spice', 'wood'},
#  '23986-74-5': {'spice', 'wood'},
#  '90-05-1': {'medicine', 'smoke', 'sweet'},
#  '489-86-1': {'balsamic', 'wood'},
#  '629-94-7': {'alkane'},
#  '629-78-7': {'alkane'},
#  '111-71-7': {'citrus', 'fat', 'rancid'},
#  '142-82-5': {'alkane'},
#  '589-82-2': {'chemical', 'green', 'herb', 'mushroom'},
#  '111-70-6': {'chemical', 'green', 'herb', 'mushroom'},
#  '543-49-7': {'chemical', 'green', 'herb', 'mushroom'},
#  '110-43-0': {'soap'},
#  '18829-55-5': {'almond', 'fat', 'soap'},
#  '2918-13-0': {'metal'},
#  '50862-12-9': {'apple'},
#  '544-76-3': {'alkane'},
#  '29354-98-1': {'flower', 'wax'},
#  '18787-63-8': {'fruit'},
#  '66-25-1': {'fat', 'grass', 'tallow'},
#  '110-54-3': {'alkane'},
#  '111-31-9': {'sulfur'},
#  '111-27-3': {'flower', 'green', 'resin'},
#  '591-78-6': {'ether', 'grape'},
#  '589-38-8': {'ether', 'grape'},
#  '1629-60-3': {'cooked vegetable', 'metal'},
#  '3681-71-8': {'banana', 'green'},
#  '142-92-7': {'fruit', 'herb'},
#  '2639-63-6': {'apple peel'},
#  '6378-65-0': {'apple peel', 'peach'},
#  '10032-15-2': {'strawberry'},
#  '1117-55-1': {'green', 'herb', 'oil'},
#  '27538-10-9': {'caramel'},
#  '20053-88-7': {'hyacinth'},
#  '19888-33-6': {'herb'},
#  '501-52-0': {'balsamic'},
#  '122-97-4': {'anise', 'cinnamon', 'fruit'},
#  '95908-33-1': {'herb'},
#  '21835-00-7': {'caramel'},
#  '3142-66-3': {'earth', 'herb', 'nut', 'truffle'},
#  '5704-20-1': {'earth', 'herb', 'nut', 'truffle'},
#  '120-72-9': {'burnt', 'mothball'},
#  '123-92-2': {'banana'},
#  '124-76-5': {'camphor', 'must'},
#  '1200-67-5': {'camphor', 'earth', 'green'},
#  '2756-56-1': {'fruit', 'turpentine'},
#  '78-83-1': {'bitter', 'solvent', 'wine'},
#  '110-19-0': {'apple', 'banana', 'fruit'},
#  '18640-74-9': {'green', 'tomato leaf'},
#  '24683-00-9': {'earth', 'green pepper', 'spice'},
#  '78-84-2': {'green', 'malt', 'pungent'},
#  '79-31-2': {'butter', 'cheese', 'rancid'},
#  '118-65-0': {'wood'},
#  '18675-35-9': {'spice', 'wood'},
#  '97-54-1': {'flower'},
#  '16750-94-0': {'rose'},
#  '5944-20-7': {'rose'},
#  '18433-98-2': {'fruit'},
#  '58615-39-7': {'fruit', 'sweet'},
#  '939-48-0': {'fruit', 'sweet'},
#  '638-11-9': {'fruit', 'pungent'},
#  '2311-46-8': {'fresh'},
#  '142-91-6': {'fat'},
#  '25773-40-4': {'earth', 'pea'},
#  '89-49-6': {'leaf', 'mint'},
#  '503-74-2': {'acid', 'cheese', 'rancid', 'sweat'},
#  '2216-51-5': {'peppermint'},
#  '143-07-7': {'metal'},
#  '112-54-9': {'citrus', 'fat', 'lily'},
#  '112-53-8': {'fat', 'wax'},
#  '498-16-8': {'herb'},
#  '23089-26-1': {'herb', 'sweet'},
#  '138-86-3': {'lemon', 'orange'},
#  '1195-92-2': {'fruit'},
#  '78-70-6': {'flower', 'lavender'},
#  '1365-19-1': {'flower', 'wood'},
#  '115-95-7': {'fruit', 'sweet'},
#  '78-36-4': {'pear', 'sweet'},
#  '115-99-1': {'citrus', 'coriander'},
#  '1118-27-0': {'apple', 'citrus', 'sweet'},
#  '10471-96-2': {'citrus', 'lavender'},
#  '108-39-4': {'fecal', 'plastic'},
#  '108-38-3': {'plastic'},
#  '118-71-8': {'caramel'},
#  '89-80-5': {'fresh', 'green', 'mint'},
#  '10458-14-7': {'fresh', 'green', 'mint'},
#  '4124-63-4': {'cabbage'},
#  '40789-98-8': {'onion'},
#  '34300-94-2': {'meat broth'},
#  '50746-10-6': {'cat', 'roast'},
#  '75832-79-0': {'black currant'},
#  '67633-97-0': {'meat', 'onion', 'roasted meat', 'sulfur'},
#  '17042-24-9': {'meat', 'onion', 'roasted meat', 'sulfur'},
#  '74-93-1': {'garlic', 'gasoline', 'sulfur'},
#  '3268-49-3': {'cooked potato'},
#  '505-10-2': {'potato', 'sweet'},
#  '94087-83-9': {'black currant', 'cat'},
#  '65505-17-1': {'cooked meat', 'meat', 'thiamin'},
#  '16630-66-3': {'cooked potato', 'roasted nut'},
#  '1115-11-3': {'fruit', 'green'},
#  '556-82-1': {'herb'},
#  '95-63-6': {'plastic'},
#  '2527-76-6': {'medicine'},
#  '134-20-3': {'flower', 'honey'},
#  '93-58-3': {'herb', 'lettuce', 'prune', 'sweet'},
#  '623-42-7': {'ether', 'fruit', 'sweet'},
#  '1754-62-7': {'strawberry'},
#  '103-26-4': {'strawberry'},
#  '4630-82-4': {'ester', 'fruit'},
#  '110-42-9': {'wine'},
#  '39647-11-5': {'jasmine'},
#  '95722-42-2': {'jasmine'},
#  '78-93-3': {'ether'},
#  '624-89-5': {'garlic', 'sulfur'},
#  '93-15-2': {'clove', 'spice'},
#  '27538-09-6': {'cotton candy', 'sweet'},
#  '1189-09-9': {'flower', 'fruit', 'green'},
#  '106-70-7': {'fresh', 'fruit', 'sweet'},
#  '1211-29-6': {'jasmine'},
#  '111-82-0': {'coconut', 'fat'},
#  '556-24-1': {'apple'},
#  '868-57-5': {'apple'},
#  '547-63-7': {'flower'},
#  '1731-84-6': {'coconut'},
#  '112-61-8': {'fat'},
#  '111-11-5': {'orange'},
#  '109-08-0': {'popcorn'},
#  '7251-61-8': {'fruit', 'nut', 'roast'},
#  '119-36-8': {'peppermint'},
#  '124-10-7': {'orris'},
#  '556-64-9': {'sulfur'},
#  '3943-74-6': {'butterscotch', 'caramel', 'vanilla'},
#  '590-86-3': {'almond', 'cocoa', 'malt'},
#  '563-80-4': {'camphor'},
#  '115-18-4': {'herb'},
#  '5287-45-6': {'amine', 'smoke'},
#  '116-53-0': {'cheese', 'sweat'},
#  '65128-99-6': {'roast'},
#  '26486-13-5': {'meat'},
#  '13679-85-1': {'cabbage', 'must', 'onion'},
#  '5616-51-3': {'sulfur'},
#  '1618-26-4': {'garlic', 'sulfur'},
#  '15707-23-0': {'roast'},
#  '33504-66-4': {'sweat'},
#  '28588-74-1': {'meat'},
#  '59303-05-8': {'roast', 'sulfur'},
#  '2371-42-8': {'earth', 'must'},
#  '110-93-0': {'mushroom', 'pepper', 'rubber'},
#  '113486-29-6': {'fruit', 'straw'},
#  '590-36-3': {'pungent'},
#  '565-69-5': {'mint'},
#  '26548-78-7': {'onion'},
#  '52558-99-3': {'garlic'},
#  '554-14-3': {'sulfur'},
#  '123-35-3': {'balsamic', 'must', 'spice'},
#  '607-91-0': {'balsamic', 'spice', 'warm'},
#  '23727-16-4': {'spice'},
#  '91-20-3': {'tar'},
#  '491-02-1': {'menthol'},
#  '106-26-3': {'lemon'},
#  '106-25-2': {'sweet'},
#  '1786-08-9': {'flower', 'oil'},
#  '40716-66-3': {'flower', 'wax', 'wood'},
#  '141-12-8': {'fruit'},
#  '6125-24-2': {'flower', 'spice'},
#  '629-92-5': {'alkane'},
#  '28069-72-9': {'cucumber'},
#  '124-19-6': {'citrus', 'fat', 'green'},
#  '111-84-2': {'alkane'},
#  '112-05-0': {'fat', 'green'},
#  '143-08-8': {'fat', 'green'},
#  '821-55-6': {'green', 'hot milk', 'soap'},
#  '5009-32-5': {'baked', 'mushroom', 'pungent'},
#  '24415-26-7': {'baked', 'mushroom', 'pungent'},
#  '143-13-5': {'fruit', 'sweet'},
#  '19322-27-1': {'caramel'},
#  '551-93-9': {'foxy', 'sweet'},
#  '95-48-7': {'phenol'},
#  '109-06-8': {'sweat'},
#  '95-47-6': {'geranium'},
#  '27400-71-1': {'herb'},
#  '502-99-8': {'fruit', 'herb', 'wet cloth'},
#  '638-66-4': {'oil'},
#  '593-45-3': {'alkane'},
#  '65767-22-8': {'geranium', 'metal'},
#  '124-13-0': {'fat', 'green', 'lemon', 'soap'},
#  '111-65-9': {'alkane'},
#  '124-07-2': {'cheese', 'sweat'},
#  '111-87-5': {'burnt', 'chemical', 'metal', 'moss', 'mushroom', 'nut'},
#  '589-98-0': {'burnt', 'chemical', 'metal', 'moss', 'mushroom', 'nut'},
#  '111-13-7': {'butter', 'gasoline', 'herb', 'resin', 'soap'},
#  '106-68-3': {'butter', 'gasoline', 'herb', 'resin', 'soap'},
#  '72755-76-1': {'metal', 'mushroom'},
#  '18409-17-1': {'mushroom', 'plastic', 'soap'},
#  '3391-86-4': {'mushroom', 'plastic', 'soap'},
#  '4312-99-6': {'metal', 'mushroom'},
#  '2051-50-5': {'fruit'},
#  '112-80-1': {'fat'},
#  '29790-29-2': {'wood'},
#  '43160-78-7': {'fat'},
#  '619-62-5': {'herb'},
#  '123-11-5': {'mint', 'sweet'},
#  '105-13-5': {'flower'},
#  '501-98-4': {'balsamic'},
#  '106-44-5': {'medicine', 'phenol', 'smoke'},
#  '99-87-6': {'citrus', 'gasoline', 'solvent'},
#  '1197-01-9': {'citrus', 'must'},
#  '123-07-9': {'phenol', 'spice'},
#  '18479-68-0': {'fruit', 'herb'},
#  '28839-13-6': {'fruit', 'herb'},
#  '32495-14-0': {'turpentine'},
#  '94268-57-2': {'turpentine'},
#  '77026-83-6': {'turpentine'},
#  '77026-84-7': {'turpentine'},
#  '18368-95-1': {'turpentine'},
#  '71159-90-5': {'grapefruit'},
#  '637-69-4': {'sweet'},
#  '7786-61-0': {'clove', 'curry'},
#  '629-80-1': {'cardboard'},
#  '599-04-2': {'cotton candy'},
#  '09.11.2765': {'fresh'},
#  '629-62-9': {'alkane'},
#  '110-62-3': {'almond', 'malt', 'pungent'},
#  '109-66-0': {'alkane'},
#  '109-52-4': {'sweat'},
#  '71-41-0': {'balsamic', 'fruit'},
#  '107-87-9': {'ether', 'fruit'},
#  '1576-87-0': {'fruit', 'strawberry', 'tomato'},
#  '616-25-1': {'butter', 'pungent'},
#  '1629-58-9': {'fish', 'pungent'},
#  '540-18-1': {'banana'},
#  '68039-26-9': {'apple'},
#  '3777-69-3': {'butter', 'green bean'},
#  '2294-76-0': {'fat'},
#  '502-69-2': {'fat'},
#  '2111-75-3': {'spice'},
#  '18031-40-8': {'fat'},
#  '539-52-6': {'wood'},
#  '108-95-2': {'phenol'},
#  '100-47-0': {'rancid'},
#  '103-82-2': {'flower', 'honey'},
#  '122-78-1': {'hawthorne', 'honey', 'sweet'},
#  '97-47-3': {'flower', 'honey'},
#  '4410-99-5': {'rubber'},
#  '150-86-7': {'flower'},
#  '168564-54-3': {'dust', 'must'},
#  '4955-29-7': {'flower'},
#  '16721-39-4': {'herb'},
#  '89-81-6': {'fresh', 'mint'},
#  '123-38-6': {'pungent', 'solvent'},
#  '79-09-4': {'pungent', 'rancid', 'soy'},
#  '71-23-8': {'alcohol', 'pungent'},
#  '1073-26-3': {'popcorn', 'roast'},
#  '133447-37-7': {'roast'},
#  '105-66-8': {'pineapple', 'solvent'},
#  '626-77-7': {'fruit'},
#  '106-36-5': {'pineapple'},
#  '123-75-1': {'alkaline'},
#  '54814-64-1': {'peach'},
#  '5471-51-2': {'raspberry'},
#  '13678-68-7': {'roast'},
#  '3387-41-5': {'pepper', 'turpentine', 'wood'},
#  '116-26-7': {'herb', 'sweet'},
#  '94-59-7': {'spice', 'sweet', 'warm'},
#  '73744-93-1': {'fruit', 'herb', 'sweet'},
#  '83-34-1': {'fecal', 'mothball'},
#  '28664-35-9': {'cotton candy', 'maple', 'spice'},
#  '6750-60-3': {'fruit', 'herb'},
#  '112-92-5': {'oil'},
#  '100-42-5': {'balsamic', 'gasoline'},
#  '25779-13-9': {'sweet'},
#  '137-00-8': {'sulfur'},
#  '67-68-5': {'garlic'},
#  '91-10-1': {'medicine', 'phenol', 'smoke'},
#  '19912-62-0': {'herb', 'weak spice'},
#  '80-26-2': {'wax'},
#  '629-59-4': {'alkane'},
#  '112-72-1': {'coconut'},
#  '124-25-4': {'flower', 'wax'},
#  '6258-63-5': {'sulfur'},
#  '110-01-0': {'cabbage'},
#  '110-02-1': {'garlic'},
#  '108-88-3': {'paint'},
#  '123-73-9': {'flower'},
#  '17699-16-0': {'balsamic', 'wood'},
#  '638-67-5': {'alkane'},
#  '10486-19-8': {'flower', 'must', 'sweet'},
#  '629-50-5': {'alkane'},
#  '112-70-9': {'must'},
#  '14667-55-1': {'must', 'potato', 'roast'},
#  '75-50-3': {'fish'},
#  '81018-77-1': {'flower', 'green'},
#  '57461-21-9': {'flower', 'green'},
#  '13623-11-5': {'earth'},
#  '1209-71-8': {'sweet', 'wax'},
#  '112-44-7': {'oil', 'pungent', 'sweet'},
#  '1120-21-4': {'alkane'},
#  '112-42-5': {'mandarin'},
#  '112-12-9': {'fresh', 'green', 'orange'},
#  '112-37-8': {'oil'},
#  '03.07.4630': {'green', 'oil'},
#  '121-33-5': {'vanilla'},
#  '552-02-3': {'green', 'sweet'},
#  '182699-77-0': {'coconut', 'spice'},
#  '58334-55-7': {'metal'},
#  '515-69-5': {'flower', 'spice'},
#  '481-34-5': {'herb', 'wood'},
#  '21391-99-1': {'wood'},
#  '4586-22-5': {'earth'},
#  '3856-25-5': {'spice', 'wood'},
#  '17699-14-8': {'herb', 'wax'},
#  '644-30-4': {'herb'},
#  '502-61-4': {'sweet', 'wood'},
#  '14575-74-7': {'camphor'},
#  '01.12.3691': {'balsamic', 'wood'},
#  '489-40-7': {'balsamic', 'wood'},
#  '6753-98-6': {'wood'},
#  '127-41-3': {'violet', 'wood'},
#  '10208-80-7': {'wood'},
#  '1195-32-0': {'citrus', 'pine'},
#  '99-83-2': {'mint', 'spice', 'turpentine'},
#  '80-56-8': {'pine', 'turpentine'},
#  '99-86-5': {'lemon'},
#  '98-55-5': {'anise', 'mint', 'oil'},
#  '02.05.2867': {'green', 'herb', 'wood'},
#  '495-60-3': {'fresh', 'sharp', 'spice'},
#  '15352-77-9': {'herb', 'sweet'},
#  '5208-59-3': {'herb'},
#  '554-60-9': {'orange peel'},
#  '87-44-5': {'spice', 'wood'},
#  '472-97-9': {'earth', 'moss'},
#  '13744-15-5': {'citrus', 'fruit'},
#  '432-25-7': {'mint'},
#  '23726-93-4': {'apple. rose', 'honey'},
#  '33880-83-0': {'fresh', 'herb', 'wax'},
#  '473-15-4': {'green', 'wood'},
#  '18794-84-8': {'citrus', 'sweet', 'wood'},
#  '58181-76-3': {'flower', 'oil'},
#  '88-84-6': {'spice', 'wood'},
#  '79-77-6': {'flower', 'raspberry', 'seaweed', 'violet'},
#  '555-10-2': {'mint', 'terpentine'},
#  '103-45-7': {'honey', 'rose', 'tobacco'},
#  '127-91-3': {'pine', 'resin', 'turpentine'},
#  '17066-67-0': {'herb'},
#  '20307-83-9': {'wood'},
#  '60066-88-8': {'sweet'},
#  '138-87-4': {'must'},
#  '96-48-0': {'caramel', 'sweet'},
#  '39029-41-9': {'wood'},
#  '706-14-9': {'fat', 'peach'},
#  '07.05.2305': {'flower', 'fruit', 'sweet'},
#  '105-21-5': {'fat', 'fruit', 'nut'},
#  '30021-74-0': {'herb', 'spice', 'wood'},
#  '104-61-0': {'coconut', 'peach'},
#  '104-50-7': {'coconut'},
#  '515-17-3': {'wood'},
#  '99-85-4': {'gasoline', 'turpentine'},
#  '104-67-6': {'apricot'},
#  '13466-78-9': {'lemon', 'resin'},
#  '483-76-1': {'medicine', 'thyme', 'wood'},
#  '36564-42-8': {'herb'},
#  '705-86-2': {'coconut', 'peach'},
#  '2825-91-4': {'coconut', 'peach'},
#  '713-95-1': {'fruit', 'sweet'},
#  '20307-84-0': {'wood'},
#  '120021-96-7': {'oil'},
#  '586-62-9': {'pine', 'plastic'},
#  '710-04-3': {'peach'}}

# %% [markdown]
# *Research data*

# %%
Research_data = pd.read_csv('./data/swri_flavorwheel.csv', sep=';')
OSA_research = Research_data['OSA'].unique()
OQ_research = Research_data['OQ'].unique()
OD_research = Research_data['OD'].unique()

# %%
Research_OD_OSA = Research_data.drop(columns=Research_data.columns[1])

# %% [markdown]
# #### create matrix with CAS OD and OSA

# %%
flavors_list = []

for cas, flavors in mol_to_OD.items():
    for flavor in flavors:
        flavors_list.append({'CAS': cas, 'OD': flavor})

CAS_OD = pd.DataFrame(flavors_list)

# %%
# Function to perform fuzzy matching
def fuzzy_match(row, df):
    matches = df[df['OD'].apply(lambda x: fuzz.partial_token_set_ratio(row['OD'], str(x).lower())) >= 80]
    if len(matches) == 1:
        return pd.Series([row['CAS'], matches.iloc[0]['OD'], matches.iloc[0]['OSA']])
    elif len(matches) > 1:
        best_match = matches.iloc[matches['OD'].apply(lambda x: fuzz.ratio(row['OD'], str(x).lower())).argmax()]
        return pd.Series([row['CAS'], best_match['OD'], best_match['OSA']])
    else:
        return pd.Series([row['CAS'], row['OD'], None])

# Apply fuzzy matching
result_df = CAS_OD.apply(lambda x: fuzzy_match(x, Research_OD_OSA), axis=1)
result_df.columns = ['CAS', 'OD', 'OSA']

# %%
# remove Nones
result_df = result_df.dropna()
print(result_df)
# Out:
#               CAS             OD           OSA
# 1       3033-23-6          Roses        Floral
# 2       3033-23-6          Sweet         Sweet
# 3      21284-22-0    Fresh herbs  Green/grassy
# 4      21284-22-0          Spicy         Spicy
# 5      21284-22-0  Green peppers  Green/grassy
# ...           ...            ...           ...
# 1330    2825-91-4   coconut milk         Nutty
# 1332     713-95-1         Fruity        Fruity
# 1333     713-95-1          Sweet         Sweet
# 1334   20307-84-0          Woody         Woody
# 1335  120021-96-7           Oily          Oily
#
# [993 rows x 3 columns]

# %%
len(set(result_df['CAS']))
# Out:
# 596

# %%
# Function to perform fuzzy matching showing also the previous odorants
def fuzzy_match_all(row, df):
    matches = df[df['OD'].apply(lambda x: fuzz.partial_token_set_ratio(row['OD'], str(x).lower())) >= 80]
    if len(matches) == 1:
        return pd.Series([row['CAS'], row['OD'], matches.iloc[0]['OD'], matches.iloc[0]['OSA']])
    elif len(matches) > 1:
        best_match = matches.iloc[matches['OD'].apply(lambda x: fuzz.ratio(row['OD'], str(x).lower())).argmax()]
        return pd.Series([row['CAS'],row['OD'], best_match['OD'], best_match['OSA']])
    else:
        return pd.Series([row['CAS'], row['OD'], None, None])

# Apply fuzzy matching
result_df_all = CAS_OD.apply(lambda x: fuzzy_match_all(x, Research_OD_OSA), axis=1)
result_df_all.columns = ['CAS', 'odorants', 'OD', 'OSA']

print(result_df_all)
# Out:
#               CAS odorants           OD           OSA
# 0       6485-40-1     mint         None          None
# 1       3033-23-6     rose        Roses        Floral
# 2       3033-23-6    sweet        Sweet         Sweet
# 3      21284-22-0     herb  Fresh herbs  Green/grassy
# 4      21284-22-0    spice        Spicy         Spicy
# ...           ...      ...          ...           ...
# 1334   20307-84-0     wood        Woody         Woody
# 1335  120021-96-7      oil         Oily          Oily
# 1336     586-62-9     pine         None          None
# 1337     586-62-9  plastic         None          None
# 1338     710-04-3    peach         None          None
#
# [1339 rows x 4 columns]

# %%
result_df_all.loc[0:5]
# Out:
#           CAS   odorants             OD           OSA
# 0   6485-40-1       mint           None          None
# 1   3033-23-6       rose          Roses        Floral
# 2   3033-23-6      sweet          Sweet         Sweet
# 3  21284-22-0       herb    Fresh herbs  Green/grassy
# 4  21284-22-0      spice          Spicy         Spicy
# 5  21284-22-0  green tea  Green peppers  Green/grassy

# %%
# create df so that CAS numbers are key and their corresponding OSAs values
cas_osa_dict = result_df.groupby('CAS')['OSA'].agg(list).to_dict()
# we could find flavors for 596 of all 702 CAS numbers
len(cas_osa_dict)
# Out:
# 596

# %% [markdown]
# *ms data*

# %%
# ms data
data = pd.read_csv('data/cas_intensities.csv', delimiter=',', index_col = 0)
# only use first repliate
data = data[data["replicate"]==1]
ms_data_original = data.drop(columns=["replicate"])
ms_data = ms_data_original.copy()
ms_data = ms_data.apply(lambda row: row/row.mean(),axis=1)
ms_data = stats.zscore(np.log(ms_data))
data_norm = ms_data.copy()
# Out:
# c:\Users\Franz\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\internals\blocks.py:351: RuntimeWarning: divide by zero encountered in log
#   result = func(self.values, **kwargs)
# c:\Users\Franz\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\_methods.py:236: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)

# %% [markdown]
# *final dataframe with available CAS numbers ODs and corresponding OSA*

# %%
filtered_data = data_norm[list(set(cas_osa_dict.keys()).intersection(data_norm.columns))]
final_matrix_CAS_to_OSA = result_df[result_df['CAS'].isin( filtered_data.columns)]
final_matrix_CAS_to_OSA
# Out:
#               CAS             OD           OSA
# 1       3033-23-6          Roses        Floral
# 2       3033-23-6          Sweet         Sweet
# 3      21284-22-0    Fresh herbs  Green/grassy
# 4      21284-22-0          Spicy         Spicy
# 5      21284-22-0  Green peppers  Green/grassy
# ...           ...            ...           ...
# 1330    2825-91-4   coconut milk         Nutty
# 1332     713-95-1         Fruity        Fruity
# 1333     713-95-1          Sweet         Sweet
# 1334   20307-84-0          Woody         Woody
# 1335  120021-96-7           Oily          Oily
#
# [993 rows x 3 columns]

# %% [markdown]
# *frequency of each OSA's occurrence*

# %%
flavor_counts = final_matrix_CAS_to_OSA['OSA'].value_counts()
flavor_counts
# Out:
# Green/grassy    175
# Fruity          146
# Nutty           137
# Oily            119
# Sweet            92
# Spicy            58
# Woody            55
# Sulphury         46
# Stale            45
# Feinty           35
# Floral           20
# Sour             19
# Cereal           15
# Peaty            14
# Soapy            12
# Solvently         5
# Name: OSA, dtype: int64

# %% [markdown]
# #### workflow for one sample

# %%
used_data = data_norm[data_norm.index=="000920"]
intensities = used_data.T
intensities.columns=['Intensity']

# %%
CAS_OD_OSA_Int = pd.merge(final_matrix_CAS_to_OSA, intensities, left_on='CAS', right_index=True, how = 'left')

# %%
CAS_OD_OSA_Int
# Out:
#               CAS             OD           OSA  Intensity
# 1       3033-23-6          Roses        Floral  -0.114381
# 2       3033-23-6          Sweet         Sweet  -0.114381
# 3      21284-22-0    Fresh herbs  Green/grassy  -0.322851
# 4      21284-22-0          Spicy         Spicy  -0.322851
# 5      21284-22-0  Green peppers  Green/grassy  -0.322851
# ...           ...            ...           ...        ...
# 1330    2825-91-4   coconut milk         Nutty   1.142312
# 1332     713-95-1         Fruity        Fruity   0.016589
# 1333     713-95-1          Sweet         Sweet   0.016589
# 1334   20307-84-0          Woody         Woody   0.676691
# 1335  120021-96-7           Oily          Oily   0.676691
#
# [993 rows x 4 columns]

# %%
final_OSAs = CAS_OD_OSA_Int.groupby('OSA')['Intensity'].sum().reset_index()
final_OSAs
# Out:
#              OSA  Intensity
# 0         Cereal   0.269729
# 1         Feinty  -3.489049
# 2         Floral  -4.947449
# 3         Fruity  14.566460
# 4   Green/grassy  28.489537
# 5          Nutty  20.612487
# 6           Oily  32.787508
# 7          Peaty   2.243662
# 8          Soapy  -1.033448
# 9      Solvently   0.758668
# 10          Sour   5.708553
# 11         Spicy   9.696774
# 12         Stale   6.873813
# 13      Sulphury   7.855567
# 14         Sweet   2.615200
# 15         Woody  16.966918

# %%
# Merge the DataFrames on 'OSA'
merged_OSA_norm = final_OSAs.merge(flavor_counts, left_on='OSA', right_index=True)
merged_OSA_norm= merged_OSA_norm.drop(columns='OSA_x')
merged_OSA_norm['norm'] = merged_OSA_norm['Intensity']/merged_OSA_norm['OSA_y']

# %%
# look at panelist 1
panelist_data_df = pd.read_table("data/vlb_data_combined.txt", delimiter=',', index_col = 1)
panelist_data_df = panelist_data_df[panelist_data_df["panelist"]==1]
panelist_data_df = panelist_data_df.drop(columns=["panelist", "date"])

# %%
merged_OSA_norm['panelist'] = merged_OSA_norm['OSA'].map(panelist_data_df.loc['000920'])
merged_OSA_norm
# Out:
#              OSA  Intensity  OSA_y      norm  panelist
# 0         Cereal   0.269729     15  0.017982       NaN
# 1         Feinty  -3.489049     35 -0.099687       NaN
# 2         Floral  -4.947449     20 -0.247372      40.0
# 3         Fruity  14.566460    146  0.099770      30.0
# 4   Green/grassy  28.489537    175  0.162797       NaN
# 5          Nutty  20.612487    137  0.150456       NaN
# 6           Oily  32.787508    119  0.275525       NaN
# 7          Peaty   2.243662     14  0.160262      30.0
# 8          Soapy  -1.033448     12 -0.086121       NaN
# 9      Solvently   0.758668      5  0.151734       NaN
# 10          Sour   5.708553     19  0.300450       NaN
# 11         Spicy   9.696774     58  0.167186       NaN
# 12         Stale   6.873813     45  0.152751       NaN
# 13      Sulphury   7.855567     46  0.170773       NaN
# 14         Sweet   2.615200     92  0.028426      40.0
# 15         Woody  16.966918     55  0.308489      50.0

# %% [markdown]
# ## define main function

# %%
def workflow(sample_key): 
    used_data = data_norm[data_norm.index==sample_key]
    intensities = used_data.T
    intensities.columns=['Intensity']
    CAS_OD_OSA_Int = pd.merge(final_matrix_CAS_to_OSA, intensities, left_on='CAS', right_index=True, how = 'left')
    final_OSAs = CAS_OD_OSA_Int.groupby('OSA')['Intensity'].sum().reset_index()
    merged_OSA_norm = final_OSAs.merge(flavor_counts, left_on='OSA', right_index=True)
    merged_OSA_norm['norm'] = merged_OSA_norm['Intensity']/merged_OSA_norm['OSA_y']
    merged_OSA_norm.columns = ['OSA', 'OSA_2','Intensity_org', ' frequency', 'Intensity']
    return merged_OSA_norm[['OSA', 'Intensity']]

# %% [markdown]
# ##### one sample

# %%
workflow('000656')
# Out:
#              OSA  Intensity
# 0         Cereal   0.101264
# 1         Feinty  -0.384747
# 2         Floral  -0.260209
# 3         Fruity  -0.301456
# 4   Green/grassy  -0.057312
# 5          Nutty   0.010776
# 6           Oily  -0.064695
# 7          Peaty   0.102872
# 8          Soapy  -0.602030
# 9      Solvently   0.030271
# 10          Sour   0.014054
# 11         Spicy  -0.210723
# 12         Stale  -0.183557
# 13      Sulphury   0.159286
# 14         Sweet  -0.201760
# 15         Woody  -0.519579

# %% [markdown]
# ##### all samples

# %%
valid_indexes = [index for index in panelist_data_df.index if index in data_norm.index]
data_all = data_norm.loc[valid_indexes]
panelist_df = panelist_data_df.loc[valid_indexes]

# %%
overlap_OSAs = ['Floral','Fruity','Sweet', 'Woody', 'Peaty']

# %%
def find_overlapping_profiles(final_OSA,comparable_OSAs):
    # show only overlap meaning: floral, fruit, sweet, wood, peat
    new_series = pd.Series(dtype='float64') 
    for comparable_OSA in comparable_OSAs:
        for index, row in final_OSA.iterrows():
            if row['OSA'] ==comparable_OSA:
                new_series[comparable_OSA] = row['Intensity']
                break
            else:
                new_series[comparable_OSA] = 0
    return(new_series)

# %%
'''
create new dataframe containing all comparable samples with the predicted OSA using the ms data
'''

def workflow_all_samples(all_samples):
    data = {"samplekey": valid_indexes}
    all_samples_OSAs= pd.DataFrame(data,columns=["samplekey",]+overlap_OSAs)
    all_samples_OSAs.set_index("samplekey", inplace=True)
    for sample_key in all_samples.index:
        OSAs = workflow(sample_key)
        OSA_compare = find_overlapping_profiles(OSAs, overlap_OSAs)
        all_samples_OSAs.loc[sample_key] = OSA_compare
    return(all_samples_OSAs)

# %%
results_all = workflow_all_samples(data_all)
results_all*10
# Out:
#               Floral    Fruity     Sweet     Woody     Peaty
# samplekey
# 000656     -2.602095 -3.014556 -2.017602 -5.195787  1.028715
# 000657     -4.929728 -5.498183 -4.280508  -7.58996 -0.436396
# 000658      -0.66514 -1.113922  1.158399  0.314365 -0.361908
# 000838     11.566884  4.410988  4.875538  9.284228 -0.342921
# 000839      4.663233 -3.608394 -0.636508  0.459512 -3.210527
# ...              ...       ...       ...       ...       ...
# 000925     -1.697807  3.440331  1.781901  3.788851 -1.434788
# 000926     -1.644645  2.246876  2.547429  2.719022  1.904119
# 000927     -1.177222  2.847173  2.350378  4.561646 -3.316097
# 000929     -1.653923  3.609984  0.682212  1.157745  0.618317
# 000930     -2.389958  4.219347  1.829187  7.937883 -2.201031
#
# [197 rows x 5 columns]

# %%
panelist_df_norm = stats.zscore(panelist_df)

# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.figure(figsize=(20,20))
i = 0
for flavor in overlap_OSAs:
    i+=1

    plt.subplot(4,3,i)
    plt.hist(panelist_df_norm[flavor], color = 'g', alpha =0.5)
    plt.hist(results_all[flavor], color='b', alpha=0.5)
    labels= ["reference","prediction"]
    plt.legend(labels)
    plt.xlabel('intensity')
    plt.ylabel('Frequency')
    plt.title(flavor + "\nCorrelation: "+ str(round(np.corrcoef(pd.to_numeric(results_all[flavor], errors='coerce').to_numpy(), np.array(panelist_df_norm[flavor]))[0,1],4)))
    
    
    plt.xlim(-3, 3)
    plt.ylim(0, 130)

plt.tight_layout()
plt.show()

# %%
samples = list(panelist_df_norm['Fruity'].index)
len(samples)
# Out:
# 197

# %%
def show_correlation_pred(prediction,reference,flavor):

    true_pos = (reference>0) & (prediction>0)
    true_neg = (reference<=0) & (prediction<=0)
    #false_pos  = (reference <= 0 ) & (pred>0)

    plt.figure(figsize=(15,5))
    
    plt.subplot(1,3,1)

    for i, sample in enumerate(samples):
        plt.plot(['reference','prediction'], [reference[i],prediction[i]], color='#7f7fff', marker='o', markersize=5)

    ticks = plt.xticks(['reference','prediction'])
    yl = plt.ylim(-3.5,3.5)

    plt.ylabel('flavor score')
    
    plt.subplot(1,3,2)
    
    plt.hist(reference, color ='g', alpha = 0.5)
    plt.hist(prediction, alpha=0.5, color ='b')
    
    plt.xlim(-3.5, 3.5)
    plt.ylim(0, 130)

    labels= ["reference","prediction"]
    plt.legend(labels)

    plt.xlabel('Intensity')
    plt.ylabel('Frequency')
    
    plt.subplot(1,3,3)
    plt.plot(prediction,reference,"o", color='b', alpha =0.5)
    
    plt.title("Correlation: "+  str(round(np.corrcoef(pd.to_numeric(prediction, errors='coerce').to_numpy(), np.array(reference))[0,1],4)))
    
    plt.xlim(-1.5,1.5)
    plt.ylim(-3.5,3.5)

    plt.suptitle(flavor)

    # Add text next to the plot
    text = ('True positive rate: ',
            round(np.sum(true_pos==True)/np.sum(prediction>0),4), '\nTrue negative rate: ', round(np.sum(true_neg==True)/np.sum(prediction<=0),4))

    plt.text(2, 0, '\n'.join(map(str, text)), fontsize=12, va='bottom', color='black')

    plt.show()

# %%
for flavor in overlap_OSAs:
    pred= results_all[flavor]
    #print(np.sum(pred>0),len(pred))
    reference=stats.zscore(panelist_df)[flavor]

    true_pos = (reference>0) & (pred>0)
    true_neg = (reference<=0) & (pred<=0)
    false_pos  = (reference <= 0 ) & (pred>0)

    '''print('True in prediction', np.sum(pred>0))
    print('True in reference', np.sum(reference>0))
    print('True in both', np.sum(true_pos==True))
    print( 'True positive rate',np.sum(true_pos==True)/np.sum(pred>0))
    print('False positive rate', np.sum(false_pos==True)/np.sum(pred>0))
    print( 'True negative rate', np.sum(true_neg==True)/np.sum(pred<=0))'''
    
    show_correlation_pred(pred, reference,flavor)
